# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="white", context="notebook", palette="deep")

COLOR_COLUMNS = ["#66C2FF", "#5CD6D6", "#00CC99", "#85E085", "#FFD966", "#FFB366", "#FFB3B3", "#DAB3FF", "#C2C2D6"]

sns.set_palette(palette=COLOR_COLUMNS, n_colors=4)

# %%
# %ls
# Out:
# Untitled.ipynb

# %%
# %cd ../datasets/
# Out:
# /Users/angelinaolmedo/term4/ds1-1/datasets

# %%
# %cd -
# Out:
# /Users/angelinaolmedo/term4/ds1-1/tutorials

# %%
FILEPATH = "../datasets/AppleStore.csv"

df = pd.read_csv(FILEPATH, index_col=0)
df
# Out:
#                                                    track_name  size_bytes  \
# id
# 281656475                                     PAC-MAN Premium   100788224
# 281796108                           Evernote - stay organized   158578688
# 281940292     WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 282614216   eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 282935706                                               Bible    92774400
# ...                                                       ...         ...
# 1188191109                                                NaN           0
# 1188375727                       Escape the Sweet Shop Series    90898432
# 1188474007                                                NaN           0
# 1188482421                                                NaN           0
# 1188524458                                                NaN           0
#
#            currency  price  rating_count_tot  rating_count_ver  user_rating  \
# id
# 281656475       USD   3.99             21292                26          4.0
# 281796108       USD   0.00            161065                26          4.0
# 281940292       USD   0.00            188583              2822          3.5
# 282614216       USD   0.00            262241               649          4.0
# 282935706       USD   0.00            985920              5320          4.5
# ...             ...    ...               ...               ...          ...
# 1188191109      NaN   0.00                 0                 0          0.0
# 1188375727      USD   0.00                 3                 3          5.0
# 1188474007      NaN   0.00                 0                 0          0.0
# 1188482421      NaN   0.00                 0                 0          0.0
# 1188524458      NaN   0.00                 0                 0          0.0
#
#             user_rating_ver     ver cont_rating   prime_genre  \
# id
# 281656475               4.5   6.3.5          4+         Games
# 281796108               3.5   8.2.2          4+  Productivity
# 281940292               4.5   5.0.0          4+       Weather
# 282614216               4.5  5.10.0         12+      Shopping
# 282935706               5.0   7.5.1          4+     Reference
# ...                     ...     ...         ...           ...
# 1188191109              0.0     NaN         NaN           NaN
# 1188375727              5.0     1.0          4+         Games
# 1188474007              0.0     NaN         NaN           NaN
# 1188482421              0.0     NaN         NaN           NaN
# 1188524458              0.0     NaN         NaN           NaN
#
#             sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic  game_enab
# id
# 281656475                38                5        10        1          0
# 281796108                37                5        23        1          0
# 281940292                37                5         3        1          0
# 282614216                37                5         9        1          0
# 282935706                37                5        45        1          0
# ...                     ...              ...       ...      ...        ...
# 1188191109                1                1         1        0          0
# 1188375727               40                0         2        1          0
# 1188474007                1                1         1        0          0
# 1188482421                1                1         1        0          0
# 1188524458                1                1         1        0          0
#
# [11100 rows x 16 columns]

# %%
df.iloc[0]
# Out:
# track_name          PAC-MAN Premium
# size_bytes                100788224
# currency                        USD
# price                          3.99
# rating_count_tot              21292
# rating_count_ver                 26
# user_rating                       4
# user_rating_ver                 4.5
# ver                           6.3.5
# cont_rating                      4+
# prime_genre                   Games
# sup_devices.num                  38
# ipadSc_urls.num                   5
# lang.num                         10
# vpp_lic                           1
# game_enab                         0
# Name: 281656475, dtype: object

# %%
df.loc[281656475]
# Out:
# track_name          PAC-MAN Premium
# size_bytes                100788224
# currency                        USD
# price                          3.99
# rating_count_tot              21292
# rating_count_ver                 26
# user_rating                       4
# user_rating_ver                 4.5
# ver                           6.3.5
# cont_rating                      4+
# prime_genre                   Games
# sup_devices.num                  38
# ipadSc_urls.num                   5
# lang.num                         10
# vpp_lic                           1
# game_enab                         0
# Name: 281656475, dtype: object

# %%
df.iloc[:3]
# Out:
#                                                 track_name  size_bytes  \
# id
# 281656475                                  PAC-MAN Premium   100788224
# 281796108                        Evernote - stay organized   158578688
# 281940292  WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
#
#           currency  price  rating_count_tot  rating_count_ver  user_rating  \
# id
# 281656475      USD   3.99             21292                26          4.0
# 281796108      USD   0.00            161065                26          4.0
# 281940292      USD   0.00            188583              2822          3.5
#
#            user_rating_ver    ver cont_rating   prime_genre  sup_devices.num  \
# id
# 281656475              4.5  6.3.5          4+         Games               38
# 281796108              3.5  8.2.2          4+  Productivity               37
# 281940292              4.5  5.0.0          4+       Weather               37
#
#            ipadSc_urls.num  lang.num  vpp_lic  game_enab
# id
# 281656475                5        10        1          0
# 281796108                5        23        1          0
# 281940292                5         3        1          0

# %%
df.head()
# Out:
#                                                   track_name  size_bytes  \
# id
# 281656475                                    PAC-MAN Premium   100788224
# 281796108                          Evernote - stay organized   158578688
# 281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 282935706                                              Bible    92774400
#
#           currency  price  rating_count_tot  rating_count_ver  user_rating  \
# id
# 281656475      USD   3.99             21292                26          4.0
# 281796108      USD   0.00            161065                26          4.0
# 281940292      USD   0.00            188583              2822          3.5
# 282614216      USD   0.00            262241               649          4.0
# 282935706      USD   0.00            985920              5320          4.5
#
#            user_rating_ver     ver cont_rating   prime_genre  sup_devices.num  \
# id
# 281656475              4.5   6.3.5          4+         Games               38
# 281796108              3.5   8.2.2          4+  Productivity               37
# 281940292              4.5   5.0.0          4+       Weather               37
# 282614216              4.5  5.10.0         12+      Shopping               37
# 282935706              5.0   7.5.1          4+     Reference               37
#
#            ipadSc_urls.num  lang.num  vpp_lic  game_enab
# id
# 281656475                5        10        1          0
# 281796108                5        23        1          0
# 281940292                5         3        1          0
# 282614216                5         9        1          0
# 282935706                5        45        1          0

# %%
df.tail()
# Out:
#                               track_name  size_bytes currency  price  \
# id
# 1188191109                           NaN           0      NaN    0.0
# 1188375727  Escape the Sweet Shop Series    90898432      USD    0.0
# 1188474007                           NaN           0      NaN    0.0
# 1188482421                           NaN           0      NaN    0.0
# 1188524458                           NaN           0      NaN    0.0
#
#             rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# id
# 1188191109                 0                 0          0.0              0.0
# 1188375727                 3                 3          5.0              5.0
# 1188474007                 0                 0          0.0              0.0
# 1188482421                 0                 0          0.0              0.0
# 1188524458                 0                 0          0.0              0.0
#
#             ver cont_rating prime_genre  sup_devices.num  ipadSc_urls.num  \
# id
# 1188191109  NaN         NaN         NaN                1                1
# 1188375727  1.0          4+       Games               40                0
# 1188474007  NaN         NaN         NaN                1                1
# 1188482421  NaN         NaN         NaN                1                1
# 1188524458  NaN         NaN         NaN                1                1
#
#             lang.num  vpp_lic  game_enab
# id
# 1188191109         1        0          0
# 1188375727         2        1          0
# 1188474007         1        0          0
# 1188482421         1        0          0
# 1188524458         1        0          0

# %%
df.price.mean()
# Out:
# 1.1192423423423423

# %%
df.describe()
# Out:
#          size_bytes         price  rating_count_tot  rating_count_ver  \
# count  1.110000e+04  11100.000000      1.110000e+04      11100.000000
# mean   1.291145e+08      1.119242      8.359482e+03        298.496486
# std    3.044624e+08      4.768515      6.129530e+04       3164.394530
# min    0.000000e+00      0.000000      0.000000e+00          0.000000
# 25%    0.000000e+00      0.000000      0.000000e+00          0.000000
# 50%    4.249093e+07      0.000000      2.000000e+01          1.000000
# 75%    1.246930e+08      0.990000      8.192500e+02         54.000000
# max    4.025970e+09    299.990000      2.974676e+06     177050.000000
#
#         user_rating  user_rating_ver  sup_devices.num  ipadSc_urls.num  \
# count  11100.000000     11100.000000     11100.000000     11100.000000
# mean       2.286802         2.109550        24.576216         2.755225
# std        2.080899         2.129825        17.621606         2.056240
# min        0.000000         0.000000         1.000000         0.000000
# 25%        0.000000         0.000000         1.000000         1.000000
# 50%        3.000000         2.000000        37.000000         2.000000
# 75%        4.500000         4.500000        38.000000         5.000000
# max        5.000000         5.000000        47.000000         5.000000
#
#            lang.num       vpp_lic  game_enab
# count  11100.000000  11100.000000    11100.0
# mean       3.875495      0.643874        0.0
# std        6.719282      0.478875        0.0
# min        0.000000      0.000000        0.0
# 25%        1.000000      0.000000        0.0
# 50%        1.000000      1.000000        0.0
# 75%        2.000000      1.000000        0.0
# max       75.000000      1.000000        0.0

# %%
df.describe(include='object')
# Out:
#                  track_name currency   ver cont_rating prime_genre
# count                  7197     7197  7197        7197        7197
# unique                 7195        1  1590           4          23
# top     Mannequin Challenge      USD   1.0          4+       Games
# freq                      2     7197   317        4433        3862

# %%
df = df.drop("currency", axis="columns")

# %%
df.describe(include='object')
# Out:
#                  track_name   ver cont_rating prime_genre
# count                  7197  7197        7197        7197
# unique                 7195  1590           4          23
# top     Mannequin Challenge   1.0          4+       Games
# freq                      2   317        4433        3862

# %%
def _byte_resizer(data):
    return np.around(data/1000000, decimals=2)

df["size_Mb"] = df["size_bytes"].apply(_byte_resizer)
df.drop("size_bytes", axis="columns", inplace=True)

# %%
df.head()
# Out:
#                                                   track_name  price  \
# id
# 281656475                                    PAC-MAN Premium   3.99
# 281796108                          Evernote - stay organized   0.00
# 281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   0.00
# 282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   0.00
# 282935706                                              Bible   0.00
#
#            rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# id
# 281656475             21292                26          4.0              4.5
# 281796108            161065                26          4.0              3.5
# 281940292            188583              2822          3.5              4.5
# 282614216            262241               649          4.0              4.5
# 282935706            985920              5320          4.5              5.0
#
#               ver cont_rating   prime_genre  sup_devices.num  ipadSc_urls.num  \
# id
# 281656475   6.3.5          4+         Games               38                5
# 281796108   8.2.2          4+  Productivity               37                5
# 281940292   5.0.0          4+       Weather               37                5
# 282614216  5.10.0         12+      Shopping               37                5
# 282935706   7.5.1          4+     Reference               37                5
#
#            lang.num  vpp_lic  game_enab  size_Mb
# id
# 281656475        10        1          0   100.79
# 281796108        23        1          0   158.58
# 281940292         3        1          0   100.52
# 282614216         9        1          0   128.51
# 282935706        45        1          0    92.77

# %%
plt.subplots(figsize=(10,8))
# Out:
# (<Figure size 720x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x12b00d9d0>)

# %%
BINS = [0.00, 10.00, 20.00, 50.00, 100.00, 200.00, 500.00, 1000.00, 2000.00, np.inf]
LABELS = ["<10m", "10-20m", "20-50m", "50-100m", "100-200m", "200-500m", "500-1000m", "1-2G", ">2G"]

# %%
freqs = pd.cut(df["size_Mb"], BINS, include_lowest=True, labels=LABELS)
sns.barplot(y=freqs.value_counts().values, x=freqs.value_counts().index)

# %%
BINS = [-np.inf, 0.00, np.inf]
LABELS = ["FREE", "PAID"]
colors = ['lightcoral', 'yellowgreen']

# %%
df["price_categories"] = pd.cut(df["price"], BINS, include_lowest=True, labels=LABELS)

# %%
df.head()
# Out:
#                                                   track_name  price  \
# id
# 281656475                                    PAC-MAN Premium   3.99
# 281796108                          Evernote - stay organized   0.00
# 281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   0.00
# 282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   0.00
# 282935706                                              Bible   0.00
#
#            rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# id
# 281656475             21292                26          4.0              4.5
# 281796108            161065                26          4.0              3.5
# 281940292            188583              2822          3.5              4.5
# 282614216            262241               649          4.0              4.5
# 282935706            985920              5320          4.5              5.0
#
#               ver cont_rating   prime_genre  sup_devices.num  ipadSc_urls.num  \
# id
# 281656475   6.3.5          4+         Games               38                5
# 281796108   8.2.2          4+  Productivity               37                5
# 281940292   5.0.0          4+       Weather               37                5
# 282614216  5.10.0         12+      Shopping               37                5
# 282935706   7.5.1          4+     Reference               37                5
#
#            lang.num  vpp_lic  game_enab  size_Mb price_categories
# id
# 281656475        10        1          0   100.79             PAID
# 281796108        23        1          0   158.58             FREE
# 281940292         3        1          0   100.52             FREE
# 282614216         9        1          0   128.51             FREE
# 282935706        45        1          0    92.77             FREE

# %%
fig, axs = plt.subplots(figsize=(10,5))

# %%
price_df = df["price_categories"].value_counts()

# %%
plt.pie(price_df.values, labels=LABELS, colors=colors, autopct='%1.1f%%', shadow=True)
centre_circle = plt.Circle((0,0),0.75, color='black', fc='white', linewidth=1.25)

fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.axis('equal')
# Out:
# (-1.1172128515167876,
#  1.1008196595960376,
#  -1.11044528544266,
#  1.1165638157433673)

# %%
df.tail()
# Out:
#                               track_name  price  rating_count_tot  \
# id
# 1188191109                           NaN    0.0                 0
# 1188375727  Escape the Sweet Shop Series    0.0                 3
# 1188474007                           NaN    0.0                 0
# 1188482421                           NaN    0.0                 0
# 1188524458                           NaN    0.0                 0
#
#             rating_count_ver  user_rating  user_rating_ver  ver cont_rating  \
# id
# 1188191109                 0          0.0              0.0  NaN         NaN
# 1188375727                 3          5.0              5.0  1.0          4+
# 1188474007                 0          0.0              0.0  NaN         NaN
# 1188482421                 0          0.0              0.0  NaN         NaN
# 1188524458                 0          0.0              0.0  NaN         NaN
#
#            prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic  \
# id
# 1188191109         NaN                1                1         1        0
# 1188375727       Games               40                0         2        1
# 1188474007         NaN                1                1         1        0
# 1188482421         NaN                1                1         1        0
# 1188524458         NaN                1                1         1        0
#
#             game_enab  size_Mb price_categories
# id
# 1188191109          0      0.0             FREE
# 1188375727          0     90.9             FREE
# 1188474007          0      0.0             FREE
# 1188482421          0      0.0             FREE
# 1188524458          0      0.0             FREE

# %%
free_apps = df.loc[df["price_categories"] == "FREE"]
paid_apps = df.loc[df["price_categories"] == "PAID"]

# %%
free_apps_rated = free_apps.sort_values(by=["rating_count_tot"], ascending=False)
paid_apps_rated = paid_apps.sort_values(by=["rating_count_tot"], ascending=False)

# %%
sns.barplot(x=free_apps_rated["rating_count_tot"][:10], y=free_apps_rated["track_name"][:10])

# %%
sns.barplot(x=paid_apps_rated["rating_count_tot"][:10], y=paid_apps_rated["track_name"][:10])

# %%
plt.subplots(figsize=(20, 20))

ratings = df.sort_values(by=["rating_count_tot"], ascending=False)

sns.barplot(x=ratings["rating_count_tot"][:30], y=ratings["track_name"][:30])

# %%
genres = df["prime_genre"].value_counts()
genres.sort_values(ascending=False, inplace=True)

plt.subplots(figsize=(20, 10))
sns.barplot(x=genres.values, y=genres.index, order=genres.index, orient="h")

# %%
games = df.loc[df["prime_genre"] == "Games"]
games.head()
# Out:
#                           track_name  price  rating_count_tot  \
# id
# 281656475            PAC-MAN Premium   3.99             21292
# 283619399           Shanghai Mahjong   0.99              8253
# 284736660                Ms. PAC-MAN   3.99              7885
# 284791396  Solitaire by MobilityWare   4.99             76720
# 284815117           SCRABBLE Premium   7.99            105776
#
#            rating_count_ver  user_rating  user_rating_ver     ver cont_rating  \
# id
# 281656475                26          4.0              4.5   6.3.5          4+
# 283619399              5516          4.0              4.0     1.8          4+
# 284736660                40          4.0              4.0   4.0.4          4+
# 284791396              4017          4.5              4.5  4.10.1          4+
# 284815117               166          3.5              2.5  5.19.0          4+
#
#           prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic  \
# id
# 281656475       Games               38                5        10        1
# 283619399       Games               47                5         1        1
# 284736660       Games               38                0        10        1
# 284791396       Games               38                4        11        1
# 284815117       Games               37                0         6        1
#
#            game_enab  size_Mb price_categories
# id
# 281656475          0   100.79             PAID
# 283619399          0    10.49             PAID
# 284736660          0    70.02             PAID
# 284791396          0    49.62             PAID
# 284815117          0   227.55             PAID

# %%
prices = (games["price"].value_counts()) / (games["price"].shape[0]) * 100
prices.sort_values(ascending=False, inplace=True)

# %%
plt.subplots(figsize=(20, 10))
ax = sns.barplot(y=prices.values, x=prices.index, order=prices.index)
ax.set(xlabel="USD", ylabel="percent (%)")
# Out:
# [Text(0, 0.5, 'percent (%)'), Text(0.5, 0, 'USD')]

# %%
free_games = games.loc[games["price_categories"] == "FREE"]
paid_games = games.loc[games["price_categories"] == "PAID"]

free_games_rated = free_games.sort_values(by=["rating_count_tot"], ascending=False)
paid_games_rated = paid_games.sort_values(by=["rating_count_tot"], ascending=False)

# %%
fig = plt.figure(figsize=(20, 10))
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

sns.barplot(x=free_games_rated["rating_count_tot"][:10], y=free_games_rated["track_name"][:10], ax=ax1)
sns.barplot(x=paid_games_rated["rating_count_tot"][:10], y=paid_games_rated["track_name"][:10], ax=ax2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-de9b7bd97dde> in <module>
# ----> 1 fig = plt.figure(figsize=(20, 10))
#       2 ax1 = fig.add_subplot(211)
#       3 ax2 = fig.add_subplot(212)
#       4
#       5 sns.barplot(x=free_games_rated["rating_count_tot"][:10], y=free_games_rated["track_name"][:10], ax=ax1)
#
# NameError: name 'plt' is not defined

# %%
free_games_rated_curr = free_games.sort_values(by=["rating_count_ver"], ascending=False)
paid_games_rated_curr = paid_games.sort_values(by=["rating_count_ver"], ascending=False)

fig = plt.figure(figsize=(20, 10))
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

sns.barplot(x=free_games_rated_curr["rating_count_ver"][:10], y=free_games_rated_curr["track_name"][:10], ax=ax1)
sns.barplot(x=paid_games_rated_curr["rating_count_ver"][:10], y=paid_games_rated_curr["track_name"][:10], ax=ax2)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

FILEPATH = "../datasets/AppleStore.csv"

df = pd.read_csv(FILEPATH, index_col=0)
df.size_bytes.mean()
# Out:
# 129114474.25036035

# %%
df.loc[df["price"] == 0.00].count()
# Out:
# track_name          4056
# size_bytes          7959
# currency            4056
# price               7959
# rating_count_tot    7959
# rating_count_ver    7959
# user_rating         7959
# user_rating_ver     7959
# ver                 4056
# cont_rating         4056
# prime_genre         4056
# sup_devices.num     7959
# ipadSc_urls.num     7959
# lang.num            7959
# vpp_lic             7959
# game_enab           7959
# dtype: int64

# %%
df.loc[df["price"] > 0.00].count()
# Out:
# track_name          3141
# size_bytes          3141
# currency            3141
# price               3141
# rating_count_tot    3141
# rating_count_ver    3141
# user_rating         3141
# user_rating_ver     3141
# ver                 3141
# cont_rating         3141
# prime_genre         3141
# sup_devices.num     3141
# ipadSc_urls.num     3141
# lang.num            3141
# vpp_lic             3141
# game_enab           3141
# dtype: int64

# %%
df.loc[df["prime_genre"] == "Games"].count()
# Out:
# track_name          3862
# size_bytes          3862
# currency            3862
# price               3862
# rating_count_tot    3862
# rating_count_ver    3862
# user_rating         3862
# user_rating_ver     3862
# ver                 3862
# cont_rating         3862
# prime_genre         3862
# sup_devices.num     3862
# ipadSc_urls.num     3862
# lang.num            3862
# vpp_lic             3862
# game_enab           3862
# dtype: int64

# %%
genres = df["prime_genre"].value_counts()
genres.sort_values(ascending=False, inplace=True)
plt.subplots(figsize=(20, 10))
sns.barplot(x=genres.values, y=genres.index, order=genres.index, orient="h")

# %%
games = df.loc[df["prime_genre"] == "Games"]
games.sort_values(by="rating_count_tot", ascending=False, inplace=True)
games.head()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                  track_name  size_bytes currency  price  rating_count_tot  \
# id
# 529479190    Clash of Clans   116476928      USD    0.0           2130805
# 420009108        Temple Run    65921024      USD    0.0           1724546
# 553834731  Candy Crush Saga   222846976      USD    0.0            961794
# 343200656       Angry Birds   175966208      USD    0.0            824451
# 512939461    Subway Surfers   156038144      USD    0.0            706110
#
#            rating_count_ver  user_rating  user_rating_ver      ver  \
# id
# 529479190               579          4.5              4.5  9.24.12
# 420009108              3842          4.5              4.0    1.6.2
# 553834731              2453          4.5              4.5  1.101.0
# 343200656               107          4.5              3.0    7.4.0
# 512939461                97          4.5              4.0   1.72.1
#
#           cont_rating prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  \
# id
# 529479190          9+       Games               38                5        18
# 420009108          9+       Games               40                5         1
# 553834731          4+       Games               43                5        24
# 343200656          4+       Games               38                0        10
# 512939461          9+       Games               38                5         1
#
#            vpp_lic  game_enab
# id
# 529479190        1          0
# 420009108        1          0
# 553834731        1          0
# 343200656        1          0
# 512939461        1          0
